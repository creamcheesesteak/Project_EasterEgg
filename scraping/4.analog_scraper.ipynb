# %%
# Appannie 용 스크래퍼

# %%
# 배운 라이브러리
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import csv
import time

# %%
# 찾아본 라이브러리
import pyautogui as gui # 마우스 이동, 키보드 입력
import pyperclip # 클립보드 사용

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')

# %%
browser.get('https://www.appannie.com/intelligence/top-apps/store-rank/ios?date=%272021-07-19%27&country_code=KR&device_code=ios-phone&category_id=100000&store_rank_ios_chart_free$previous_range$chart_compare_facets=!(store_product_rank_grossing__aggr)&store-rank.ios.view=free&store_rank.ios.chart_range=7')

# %%
# 스크래퍼 작동을 위해 화면이 top에 위치 & 페이지크기 full
browser.maximize_window()
browser.implicitly_wait(10)

# %%
html= browser.page_source

# %%
browser.execute_script("window.scrollTo(0, 950)")

# %%
contents = []

# 1 ~ 91 순위까지
for i in range(1, 92):
    gui.moveTo(490,236,1)
    gui.dragTo(1173, 280, 1,button='left')
    gui.hotkey('ctrl','c')
    a = pyperclip.paste()
    gui.click()
    gui.scroll(-60)
    list = a.split('\r')
    list = [i.strip('\n') for i in list]
    time.sleep(0.6)
    if len(list) == 3:
        list.insert(2, '없음')
        contents.append(list)
        continue
    elif len(list) == 4:
        contents.append(list)
        continue
#     else:
#         break

# %%
# 92 ~ 100 순위 까지 (마지막은 스크롤을 내릴 수 없어서 따로 for문 작성)
for i in range(1,10):
    n = 75 * (i-1)
    gui.moveTo(490,236+int(n),1)
    gui.dragTo(1173, 280+int(n), 1,button='left')
    gui.hotkey('ctrl','c')
    a = pyperclip.paste()
    gui.click()
    list = a.split('\r')
    list = [i.strip('\n') for i in list]
    time.sleep(0.5)
    if len(list) == 3:
        list.insert(2, '없음')
        contents.append(list)
        continue
    elif len(list) == 4:
        contents.append(list)
        continue

# %%
len(contents)
# Out:
# 100

# %%
contents
# Out:
# [['', '질병관리청 COOV(코로나19 전자예방접종증명서)', '질병관리본부', 'Medical (Applications)'],
#  ['', 'Time Princess: Dress Up', 'IGG', 'Games'],
#  ['',
#   'Karrot - Buy & sell locally',
#   'Danggeun Market',
#   'Social Networking (Applications)'],
#  ['', '배달의민족', 'Woowa Brothers', 'Food and Drink (Applications)'],
#  ['', 'Coupang Eats', 'Coupang', 'Food and Drink (Applications)'],
#  ['', 'TikTok ティックトック', 'TikTok Pte Ltd', 'Entertainment (Applications)'],
#  ['',
#   'ZOOM Cloud Meetings',
#   'Zoom Video Communications',
#   'Business (Applications)'],
#  ['', 'KakaoTalk', 'Kakao', 'Social Networking (Applications)'],
#  ['', 'Instagram', 'Instagram', 'Photo and Video (Applications)'],
#  ['', 'Kakao T', 'Kakao Mobility', 'Travel (Application'],
#  ['', '네이버 - NAVER', 'NAVER', 'Reference (Applications)'],
#  ['', '청약홈', 'Korea Appraisal Board', 'Finance (Applications)'],
#  ['', '쿠팡 - Coupang', 'Coupang', 'Shopping (Applications)'],
#  ['', '티빙(tving)', 'CJ ENM', 'Entertainment (Applications)'],
#  ['', 'Judgement Day: Heaven or Hell', 'Matchingham Games', 'Games'],
#  ['', '야놀자', 'Yanolja', 'Travel (Application'],
#  ['',
#   'YouTube: Watch, Listen, Stream',
#   'Google',
#   'Photo and Video (Applications)'],
#  ['', 'Paper Fold', 'Good Job Games', 'Games'],
#  ['', 'Netflix', 'Netflix', 'Entertainment (Applications)'],
#  ['', 'NAVER Map, Navigation', 'NAVER', 'Navigation (Applications)'],
#  ['', '카카오뱅크', 'Kakao Bank', 'Finance (Applications)'],
#  ['', 'Google Chrome', 'Google', 'Utilities (Applications)'],
#  ['',
#   'todo mate - widget, reminder',
#   'Yoon Sik Kang',
#   'Productivity (Applications)'],
#  ['',
#   '자가격리자 안전보호',
#   'Ministry of the Interior and Safety',
#   'Lifestyle (Applications)'],
#  ['', '다방 - 대한민국 대표 부동산 앱', 'Station3', 'Lifestyle (Applications)'],
#  ['', '오늘의집 - No.1 인테리어 필수앱', 'Bucketplace', 'Shopping (Applications)'],
#  ['', 'IG Views: Unfollowers tracker', '없음', 'Utilities (Applications)'],
#  ['', '여기어때 - 호텔, 모텔, 펜션 최저가 예약!', 'GC Company', 'Travel (Application'],
#  ['',
#   '배달요기요 - 기다림 없는 맛집 배달앱',
#   'Delivery Hero Korea',
#   'Food and Drink (Applications)'],
#  ['', 'Fidget Trading 3D: Fidget Toys', 'Maglab Turkey', 'Games'],
#  ['', 'Count Masters: Crowd Runner 3D', 'Tapinator', 'Games'],
#  ['', 'KakaoMap - Korea No.1 Map', 'Daum', 'Navigation (Applications)'],
#  ['',
#   'SNOW - Beauty & makeup camera',
#   'SNOW, Inc.',
#   'Photo and Video (Applications)'],
#  ['', 'Rummikub', 'Kinkajoo', 'Games'],
#  ['', 'Facebook', 'Facebook', 'Social Networking (Applications)'],
#  ['',
#   'BAND - App for all groups',
#   'NAVER',
#   'Social Networking (Applications)'],
#  ['',
#   '정부24(구 민원24)',
#   'Ministry of the Interior and Safety',
#   'Lifestyle (Applications)'],
#  ['', '카카오페이', 'Kakao', 'Finance (Applications)'],
#  ['', '제주안심코드', '제주특별자치도', 'Health and Fitness (Applications)'],
#  ['', '쿠팡플레이', 'Coupang', 'Entertainment (Applications)'],
#  ['', '브랜디 – 하루배송', 'Brandi', 'Shopping (Applications)'],
#  ['', 'KB증권 M-able(계좌개설겸용)', 'KB Securities', 'Finance (Applications)'],
#  ['', 'ISP/페이북', 'VP Inc', 'Finance (Applications)'],
#  ['', '네이버 웹툰 - Naver Webtoon', 'NAVER', 'Entertainment (Applications)'],
#  ['', '스타벅스', 'Starbucks Korea', 'Food and Drink (Applications)'],
#  ['', '교촌치킨', 'Kyochon', 'Food and Drink (Applications)'],
#  ['', '왓챠 - WATCHA', 'Watcha', 'Entertainment (Applications)'],
#  ['', 'Google', 'Google', 'Utilities (Applications)'],
#  ['', 'Snapchat', 'Snap', 'Photo and Video (Applications)'],
#  ['', '온라인 패션 스토어 무신사', 'Musinsa', 'Shopping (Applications)'],
#  ['', 'Messenger', 'Facebook', 'Social Networking (Applications)'],
#  ['', 'Infinite Stairs', 'NFLY STUDIO', 'Games'],
#  ['', '에이블리 - 2천만의 AI 쇼핑메이트', 'PaletteCo', 'Shopping (Applications)'],
#  ['', '멜론(Melon)', 'Kakao M', 'Music (Application'],
#  ['',
#   'The건강보험',
#   'National Health Insurance Corporation',
#   'Medical (Applications)'],
#  ['', '토스', 'Viva Republica', 'Finance (Applications)'],
#  ['', 'Gmail - Email by Google', 'Google', 'Productivity (Applications)'],
#  ['', 'TMAP - 내비게이션 / 지도', 'TMAP MOBILITY', 'Navigation (Applications)'],
#  ['', 'GSSHOP', 'GS Retail', 'Shopping (Applications)'],
#  ['', '직방 - No.1 부동산 앱', 'Channelbreeze', 'Lifestyle (Applications)'],
#  ['', 'TheDayBefore (days countdown)', 'iBill', 'Lifestyle (Applications)'],
#  ['', 'PUBG MOBILE', 'PUBG Corporation', 'Games'],
#  ['', 'KartRider Rush+', 'NEXON', 'Games'],
#  ['', '테이블링', '밀랑', 'Food and Drink (Applications)'],
#  ['', '쇼아 - 쇼핑몰 모음앱', '없음', 'Shopping (Applications)'],
#  ['', '마켓컬리', 'Kurly', 'Food and Drink (Applications)'],
#  ['', 'wavve(웨이브)', 'Wavve', 'Entertainment (Applications)'],
#  ['', '번개장터 - 취향을 잇는 거래', 'Quicket', 'Shopping (Applications)'],
#  ['',
#   'SODA - Natural Beauty Camera',
#   'SNOW, Inc.',
#   'Photo and Video (Applications)'],
#  ['',
#   'Voilà AI Artist Cartoon Photo',
#   'Wemagine.ai',
#   'Photo and Video (Applications)'],
#  ['', 'YouTube Music', 'Google', 'Music (Application'],
#  ['', 'Sumone', 'sandfox', 'Lifestyle (Applications)'],
#  ['', '알바몬 - 알바 채용 전문', 'Jobkorea', 'Business (Applications)'],
#  ['', '올리브영', 'CJ Olive Young', 'Lifestyle (Applications)'],
#  ['', 'Trading Master 3D - Fidget Pop', 'Panteon', 'Games'],
#  ['', 'Naver Papago - AI Translator', 'NAVER', 'Reference (Applications)'],
#  ['', 'NH스마트뱅킹', 'Nonghyup', 'Finance (Applications)'],
#  ['', 'Twitter', 'Twitter', 'News (Applications'],
#  ['', 'KB스타뱅킹', 'KB Bank', 'Finance (Applications)'],
#  ['', 'InBody', '없음', 'Health and Fitness (Applications)'],
#  ['', 'Nike Run Club', 'Nike', 'Health and Fitness (Applications)'],
#  ['', '네이버 블로그 - Naver Blog', 'NAVER', 'Social Networking (Applications)'],
#  ['',
#   '하나원큐프로 - 하나금융투자(비대면계좌개설 포함)',
#   'Hana Financial Investment',
#   'Finance (Applications)'],
#  ['',
#   'Zenly - Your map, your people',
#   'Zenly',
#   'Social Networking (Applications)'],
#  ['', '코레일톡4', 'KORAIL', 'Travel (Application'],
#  ['', '투썸하트', 'A TWOSOME PLACE', 'Lifestyle (Applications)'],
#  ['', 'Airbnb', 'Airbnb', 'Travel (Application'],
#  ['', '발란 - 참 쉬운 럭셔리 쇼핑 앱', 'BALAAN', 'Shopping (Applications)'],
#  ['', 'KREAM - 한정판 거래의 FLEX', 'KREAM Corporation', 'Shopping (Applications)'],
#  ['', 'Pinterest', 'Pinterest', 'Lifestyle (Applications)'],
#  ['', '클로바노트 - AI 음성기록', 'NAVER', 'Productivity (Applications)'],
#  ['', '맘스터치', '없음', 'Food and Drink (Applications)'],
#  ['', 'Clockology', '', 'Graphics & Design (Applications)'],
#  ['', '해피오더', 'SPC Group', 'Lifestyle (Applications)'],
#  ['', 'Liar Game', 'DongUk Kim', 'Games'],
#  ['', '알바천국', 'Mediawill', 'Business (Applications)'],
#  ['', '하나원큐 - 하나은행 스마트폰 뱅킹', 'KEB Hana Bank', 'Finance (Applications)'],
#  ['', 'ZEPETO', 'SNOW, Inc.', 'Social Networking (Applications)'],
#  ['', 'NAVER MYBOX', 'NAVER', 'Utilities (Applications)'],
#  ['', 'Going Balls', 'Supersonic', 'Games']]

# %%
# 드래그시 열의 마지막 str에서 긴 (Application) 의 경우 1~2문자의 누락가능성 확인 -> 조정하기위한 for문
for content in contents:
    if content[-1][-1] == 'n':
        content[-1] = content[-1] + 's)'
    elif content[-1][-1] == 'o':
        content[-1] = content[-1] + 'ns)'
    elif (content[-1] == 'Games') or (content[-1] == 'Kids'):
        break
    elif content[-1][-1] == 's':
        content[-1] = content[-1] + ')'

# %%
pd.set_option('display.max_row', 101)
pd.set_option('display.max_columns', 10)

# %%
df = pd.DataFrame(data = contents, columns = ['-', '앱이름','회사명','카테고리'])
df.index = df.index + 1
df = df.drop(columns = ['-'])
df
# Out:
#                                 앱이름                                    회사명  \
# 1       질병관리청 COOV(코로나19 전자예방접종증명서)                                 질병관리본부
# 2           Time Princess: Dress Up                                    IGG
# 3       Karrot - Buy & sell locally                        Danggeun Market
# 4                             배달의민족                         Woowa Brothers
# 5                      Coupang Eats                                Coupang
# 6                    TikTok ティックトック                         TikTok Pte Ltd
# 7               ZOOM Cloud Meetings              Zoom Video Communications
# 8                         KakaoTalk                                  Kakao
# 9                         Instagram                              Instagram
# 10                          Kakao T                         Kakao Mobility
# 11                      네이버 - NAVER                                  NAVER
# 12                              청약홈                  Korea Appraisal Board
# 13                     쿠팡 - Coupang                                Coupang
# 14                        티빙(tving)                                 CJ ENM
# 15    Judgement Day: Heaven or Hell                      Matchingham Games
# 16                              야놀자                                Yanolja
# 17   YouTube: Watch, Listen, Stream                                 Google
# 18                       Paper Fold                         Good Job Games
# 19                          Netflix                                Netflix
# 20            NAVER Map, Navigation                                  NAVER
# 21                            카카오뱅크                             Kakao Bank
# 22                    Google Chrome                                 Google
# 23     todo mate - widget, reminder                          Yoon Sik Kang
# 24                       자가격리자 안전보호    Ministry of the Interior and Safety
# 25               다방 - 대한민국 대표 부동산 앱                               Station3
# 26             오늘의집 - No.1 인테리어 필수앱                            Bucketplace
# 27    IG Views: Unfollowers tracker                                     없음
# 28        여기어때 - 호텔, 모텔, 펜션 최저가 예약!                             GC Company
# 29            배달요기요 - 기다림 없는 맛집 배달앱                    Delivery Hero Korea
# 30   Fidget Trading 3D: Fidget Toys                          Maglab Turkey
# 31   Count Masters: Crowd Runner 3D                              Tapinator
# 32        KakaoMap - Korea No.1 Map                                   Daum
# 33    SNOW - Beauty & makeup camera                             SNOW, Inc.
# 34                         Rummikub                               Kinkajoo
# 35                         Facebook                               Facebook
# 36        BAND - App for all groups                                  NAVER
# 37                     정부24(구 민원24)    Ministry of the Interior and Safety
# 38                            카카오페이                                  Kakao
# 39                           제주안심코드                                제주특별자치도
# 40                            쿠팡플레이                                Coupang
# 41                       브랜디 – 하루배송                                 Brandi
# 42              KB증권 M-able(계좌개설겸용)                          KB Securities
# 43                          ISP/페이북                                 VP Inc
# 44           네이버 웹툰 - Naver Webtoon                                  NAVER
# 45                             스타벅스                        Starbucks Korea
# 46                             교촌치킨                                Kyochon
# 47                      왓챠 - WATCHA                                 Watcha
# 48                           Google                                 Google
# 49                         Snapchat                                   Snap
# 50                   온라인 패션 스토어 무신사                                Musinsa
# 51                        Messenger                               Facebook
# 52                  Infinite Stairs                            NFLY STUDIO
# 53             에이블리 - 2천만의 AI 쇼핑메이트                              PaletteCo
# 54                        멜론(Melon)                                Kakao M
# 55                          The건강보험  National Health Insurance Corporation
# 56                               토스                         Viva Republica
# 57          Gmail - Email by Google                                 Google
# 58                TMAP - 내비게이션 / 지도                          TMAP MOBILITY
# 59                           GSSHOP                              GS Retail
# 60                  직방 - No.1 부동산 앱                          Channelbreeze
# 61    TheDayBefore (days countdown)                                  iBill
# 62                      PUBG MOBILE                       PUBG Corporation
# 63                  KartRider Rush+                                  NEXON
# 64                             테이블링                                     밀랑
# 65                     쇼아 - 쇼핑몰 모음앱                                     없음
# 66                             마켓컬리                                  Kurly
# 67                       wavve(웨이브)                                  Wavve
# 68                 번개장터 - 취향을 잇는 거래                                Quicket
# 69     SODA - Natural Beauty Camera                             SNOW, Inc.
# 70    Voilà AI Artist Cartoon Photo                            Wemagine.ai
# 71                    YouTube Music                                 Google
# 72                           Sumone                                sandfox
# 73                   알바몬 - 알바 채용 전문                               Jobkorea
# 74                             올리브영                         CJ Olive Young
# 75   Trading Master 3D - Fidget Pop                                Panteon
# 76     Naver Papago - AI Translator                                  NAVER
# 77                          NH스마트뱅킹                               Nonghyup
# 78                          Twitter                                Twitter
# 79                           KB스타뱅킹                                KB Bank
# 80                           InBody                                     없음
# 81                    Nike Run Club                                   Nike
# 82             네이버 블로그 - Naver Blog                                  NAVER
# 83      하나원큐프로 - 하나금융투자(비대면계좌개설 포함)              Hana Financial Investment
# 84    Zenly - Your map, your people                                  Zenly
# 85                            코레일톡4                                 KORAIL
# 86                             투썸하트                        A TWOSOME PLACE
# 87                           Airbnb                                 Airbnb
# 88               발란 - 참 쉬운 럭셔리 쇼핑 앱                                 BALAAN
# 89             KREAM - 한정판 거래의 FLEX                      KREAM Corporation
# 90                        Pinterest                              Pinterest
# 91                  클로바노트 - AI 음성기록                                  NAVER
# 92                             맘스터치                                     없음
# 93                       Clockology
# 94                             해피오더                              SPC Group
# 95                        Liar Game                             DongUk Kim
# 96                             알바천국                              Mediawill
# 97              하나원큐 - 하나은행 스마트폰 뱅킹                          KEB Hana Bank
# 98                           ZEPETO                             SNOW, Inc.
# 99                      NAVER MYBOX                                  NAVER
# 100                     Going Balls                             Supersonic
#
#                                   카테고리
# 1               Medical (Applications)
# 2                                Games
# 3     Social Networking (Applications)
# 4        Food and Drink (Applications)
# 5        Food and Drink (Applications)
# 6         Entertainment (Applications)
# 7              Business (Applications)
# 8     Social Networking (Applications)
# 9       Photo and Video (Applications)
# 10                 Travel (Application
# 11            Reference (Applications)
# 12              Finance (Applications)
# 13             Shopping (Applications)
# 14        Entertainment (Applications)
# 15                               Games
# 16                 Travel (Application
# 17      Photo and Video (Applications)
# 18                               Games
# 19        Entertainment (Applications)
# 20           Navigation (Applications)
# 21              Finance (Applications)
# 22            Utilities (Applications)
# 23         Productivity (Applications)
# 24            Lifestyle (Applications)
# 25            Lifestyle (Applications)
# 26             Shopping (Applications)
# 27            Utilities (Applications)
# 28                 Travel (Application
# 29       Food and Drink (Applications)
# 30                               Games
# 31                               Games
# 32           Navigation (Applications)
# 33      Photo and Video (Applications)
# 34                               Games
# 35    Social Networking (Applications)
# 36    Social Networking (Applications)
# 37            Lifestyle (Applications)
# 38              Finance (Applications)
# 39   Health and Fitness (Applications)
# 40        Entertainment (Applications)
# 41             Shopping (Applications)
# 42              Finance (Applications)
# 43              Finance (Applications)
# 44        Entertainment (Applications)
# 45       Food and Drink (Applications)
# 46       Food and Drink (Applications)
# 47        Entertainment (Applications)
# 48            Utilities (Applications)
# 49      Photo and Video (Applications)
# 50             Shopping (Applications)
# 51    Social Networking (Applications)
# 52                               Games
# 53             Shopping (Applications)
# 54                  Music (Application
# 55              Medical (Applications)
# 56              Finance (Applications)
# 57         Productivity (Applications)
# 58           Navigation (Applications)
# 59             Shopping (Applications)
# 60            Lifestyle (Applications)
# 61            Lifestyle (Applications)
# 62                               Games
# 63                               Games
# 64       Food and Drink (Applications)
# 65             Shopping (Applications)
# 66       Food and Drink (Applications)
# 67        Entertainment (Applications)
# 68             Shopping (Applications)
# 69      Photo and Video (Applications)
# 70      Photo and Video (Applications)
# 71                  Music (Application
# 72            Lifestyle (Applications)
# 73             Business (Applications)
# 74            Lifestyle (Applications)
# 75                               Games
# 76            Reference (Applications)
# 77              Finance (Applications)
# 78                  News (Applications
# 79              Finance (Applications)
# 80   Health and Fitness (Applications)
# 81   Health and Fitness (Applications)
# 82    Social Networking (Applications)
# 83              Finance (Applications)
# 84    Social Networking (Applications)
# 85                 Travel (Application
# 86            Lifestyle (Applications)
# 87                 Travel (Application
# 88             Shopping (Applications)
# 89             Shopping (Applications)
# 90            Lifestyle (Applications)
# 91         Productivity (Applications)
# 92       Food and Drink (Applications)
# 93    Graphics & Design (Applications)
# 94            Lifestyle (Applications)
# 95                               Games
# 96             Business (Applications)
# 97              Finance (Applications)
# 98    Social Networking (Applications)
# 99            Utilities (Applications)
# 100                              Games

# %% [markdown]
# * Games : Action, Adventure, Board, Card, Casino, Casual, Dice, Education, Family, Kids, Music, Puzzle, Racing, Role Playing, Simulation, Sports, Strategy, Trivia, Word
#
# * Applications : Books, Business, Catalogs, Developer Tools, Education, Entertainment, Finance, Food and Drink, Graphics & Design, Health and Fitness, Lifestyle, Magazines and Newspapers, Medical, Music, Navigation, News, Photo and Video, Productivity, Reference, Shopping, Social Networking, Sports, Travel, Utilities, Weather
#
# * Kids : Ages 5 & Under, Ages 6-8, Ages 9-11

# %%
# 회사명 中 None 은 '없음' 으로 본다

# %%
df.to_excel('C:\pl/contents.xls')
