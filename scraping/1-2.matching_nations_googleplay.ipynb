# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import csv
import time

# %%
import pyautogui as gui
import pyperclip

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')

# %%
browser.get('https://www.appannie.com/account/login')

# %%
## 로그인 후 tab -> top charts 이동

# %%
total = ['Jordan',
 'Turks and Caicos Islands',
 'Mozambique',
 'Ireland',
 'Vietnam',
 'Algeria',
 'Latvia',
 'Tajikistan',
 'Laos',
 'Gibraltar',
 'Kuwait',
 'Monaco',
 'Slovenia',
 'Angola',
 'Singapore',
 'Central African Republic',
 'United Kingdom',
 'Belgium',
 'Argentina',
 'Portugal',
 'Romania',
 'Colombia',
 'Tanzania',
 'Liechtenstein',
 'Dominican Republic',
 'Iraq',
 'Israel',
 'Samoa',
 'Thailand',
 'Czech Republic',
 'Indonesia',
 'Zambia',
 'British Virgin Islands',
 'Chad',
 'Cuba',
 'Venezuela',
 'Sierra Leone',
 'Bulgaria',
 'Lithuania',
 'Tunisia',
 'Georgia',
 'St. Lucia',
 'Taiwan',
 'South Korea',
 'Suriname',
 'Austria',
 'Azerbaijan',
 'Macau',
 'Eritrea',
 'Cape Verde',
 'Guinea-Bissau',
 'Senegal',
 'Tonga',
 'Germany',
 'Yemen',
 'Oman',
 'Guatemala',
 'Mauritius',
 'Moldova',
 'Zimbabwe',
 "Cote d'Ivoire",
 'Hungary',
 'Nicaragua',
 'Panama',
 'Ecuador',
 'Uzbekistan',
 'Belize',
 'Mexico',
 'Kenya',
 'Pakistan',
 'Jamaica',
 'Peru',
 'Togo',
 'Grenada',
 'Slovakia',
 'Brazil',
 'Norway',
 'Libya',
 'Bermuda',
 'Lebanon',
 'Rwanda',
 'Hong Kong',
 'Papua New Guinea',
 'Chile',
 'Italy',
 'Djibouti',
 'Ghana',
 'Cyprus',
 'Iceland',
 'St. Kitts & Nevis',
 'Cameroon',
 'Paraguay',
 'Croatia',
 'Guinea',
 'Antigua and Barbuda',
 'Vanuatu',
 'Maldives',
 'Myanmar',
 'Morocco',
 'Somalia',
 'Netherlands Antilles',
 'Burkina Faso',
 'Bosnia and Herzegovina',
 'Malta',
 'Iran',
 'Niger',
 'Canada',
 'Gabon',
 'Kyrgyzstan',
 'Sweden',
 'South Africa',
 'Turkey',
 'Bolivia',
 'Philippines',
 'Armenia',
 'China',
 'Micronesia',
 'Namibia',
 'Bahamas',
 'Uruguay',
 'Aruba',
 'Kazakhstan',
 'Mali',
 'Nepal',
 'Sudan',
 'New Zealand',
 'Nigeria',
 'Uganda',
 'Trinidad and Tobago',
 'Fiji',
 'Sri Lanka',
 'Haiti',
 'India',
 'Japan',
 'Belarus',
 'Comoros',
 'Dominica',
 'Costa Rica',
 'Greece',
 'Honduras',
 'Gambia',
 'Saudi Arabia',
 'United Arab Emirates',
 'Bahrain',
 'El Salvador',
 'Switzerland',
 'Cambodia',
 'Spain',
 'Botswana',
 'Luxembourg',
 'Seychelles',
 'Malaysia',
 'Liberia',
 'Cayman Islands',
 'San Marino',
 'Turkmenistan',
 'Estonia',
 'Qatar',
 'Australia',
 'Poland',
 'Benin',
 'Barbados',
 'Bangladesh',
 'Serbia',
 'Netherlands',
 'Solomon Islands',
 'Egypt',
 'Albania',
 'Finland',
 'Ukraine',
 'France',
 'Denmark',
 'Congo',
 'Russia',
 'United States']
gui.moveTo(400,300)

# %%
len(total)
# Out:
# 175

# %%
right = []
false = []
for name in total:
    now = browser.current_url
    nation = browser.find_element_by_xpath("//input[@aria-activedescendant='react-select-SingleCountryPicker--store_rank_release_time_as_date_capacity--value']")
    nation.send_keys(name) # 국가명 입력
    nation.send_keys(Keys.RETURN)
    gui.moveTo(400,300, 1)
    if browser.current_url != now:
        right.append(name)
    else:
        false.append(name)
    gui.click()
#     try:
#         right.append(name)
#         continue
#     except NoSuchElementException:
#         false.append(name)
#         continue

# %%
print(right), print(false)
# Out:
# ['Jordan', 'Ireland', 'Vietnam', 'Algeria', 'Latvia', 'Kuwait', 'Slovenia', 'Singapore', 'United Kingdom', 'Belgium', 'Argentina', 'Portugal', 'Romania', 'Colombia', 'Tanzania', 'Dominican Republic', 'Iraq', 'Israel', 'Thailand', 'Czech Republic', 'Indonesia', 'Venezuela', 'Bulgaria', 'Lithuania', 'Tunisia', 'Taiwan', 'South Korea', 'Austria', 'Azerbaijan', 'Macau', 'Germany', 'Yemen', 'Oman', 'Guatemala', 'Moldova', 'Hungary', 'Panama', 'Ecuador', 'Uzbekistan', 'Mexico', 'Kenya', 'Pakistan', 'Jamaica', 'Peru', 'Slovakia', 'Brazil', 'Norway', 'Lebanon', 'Hong Kong', 'Chile', 'Italy', 'Ghana', 'Paraguay', 'Croatia', 'Morocco', 'Bosnia and Herzegovina', 'Iran', 'Niger', 'Canada', 'Kyrgyzstan', 'Sweden', 'South Africa', 'Turkey', 'Bolivia', 'Philippines', 'Armenia', 'China', 'Uruguay', 'Kazakhstan', 'Nepal', 'New Zealand', 'Nigeria', 'Trinidad and Tobago', 'Sri Lanka', 'India', 'Japan', 'Belarus', 'Dominica', 'Costa Rica', 'Greece', 'Honduras', 'Saudi Arabia', 'United Arab Emirates', 'Bahrain', 'El Salvador', 'Switzerland', 'Cambodia', 'Spain', 'Luxembourg', 'Malaysia', 'Qatar', 'Australia', 'Poland', 'Bangladesh', 'Serbia', 'Netherlands', 'Egypt', 'Finland', 'Ukraine', 'France', 'Denmark', 'Russia', 'United States']
# ['Turks and Caicos Islands', 'Mozambique', 'Tajikistan', 'Laos', 'Gibraltar', 'Monaco', 'Angola', 'Central African Republic', 'Liechtenstein', 'Samoa', 'Zambia', 'British Virgin Islands', 'Chad', 'Cuba', 'Sierra Leone', 'Georgia', 'St. Lucia', 'Suriname', 'Eritrea', 'Cape Verde', 'Guinea-Bissau', 'Senegal', 'Tonga', 'Mauritius', 'Zimbabwe', "Cote d'Ivoire", 'Nicaragua', 'Belize', 'Togo', 'Grenada', 'Libya', 'Bermuda', 'Rwanda', 'Papua New Guinea', 'Djibouti', 'Cyprus', 'Iceland', 'St. Kitts & Nevis', 'Cameroon', 'Guinea', 'Antigua and Barbuda', 'Vanuatu', 'Maldives', 'Myanmar', 'Somalia', 'Netherlands Antilles', 'Burkina Faso', 'Malta', 'Gabon', 'Micronesia', 'Namibia', 'Bahamas', 'Aruba', 'Mali', 'Sudan', 'Uganda', 'Fiji', 'Haiti', 'Comoros', 'Gambia', 'Botswana', 'Seychelles', 'Liberia', 'Cayman Islands', 'San Marino', 'Turkmenistan', 'Estonia', 'Benin', 'Barbados', 'Solomon Islands', 'Albania', 'Congo']
# (None, None)

# %%
len(right), len(false)
# Out:
# (103, 72)

# %%
a = 'Jordan'
right.append(a)

# %%
right
# Out:
# ['Jordan',
#  'Ireland',
#  'Vietnam',
#  'Algeria',
#  'Latvia',
#  'Kuwait',
#  'Slovenia',
#  'Singapore',
#  'United Kingdom',
#  'Belgium',
#  'Argentina',
#  'Portugal',
#  'Romania',
#  'Colombia',
#  'Tanzania',
#  'Dominican Republic',
#  'Iraq',
#  'Israel',
#  'Thailand',
#  'Czech Republic',
#  'Indonesia',
#  'Venezuela',
#  'Bulgaria',
#  'Lithuania',
#  'Tunisia',
#  'Taiwan',
#  'South Korea',
#  'Austria',
#  'Azerbaijan',
#  'Macau',
#  'Germany',
#  'Yemen',
#  'Oman',
#  'Guatemala',
#  'Moldova',
#  'Hungary',
#  'Panama',
#  'Ecuador',
#  'Uzbekistan',
#  'Mexico',
#  'Kenya',
#  'Pakistan',
#  'Jamaica',
#  'Peru',
#  'Slovakia',
#  'Brazil',
#  'Norway',
#  'Lebanon',
#  'Hong Kong',
#  'Chile',
#  'Italy',
#  'Ghana',
#  'Paraguay',
#  'Croatia',
#  'Morocco',
#  'Bosnia and Herzegovina',
#  'Iran',
#  'Niger',
#  'Canada',
#  'Kyrgyzstan',
#  'Sweden',
#  'South Africa',
#  'Turkey',
#  'Bolivia',
#  'Philippines',
#  'Armenia',
#  'China',
#  'Uruguay',
#  'Kazakhstan',
#  'Nepal',
#  'New Zealand',
#  'Nigeria',
#  'Trinidad and Tobago',
#  'Sri Lanka',
#  'India',
#  'Japan',
#  'Belarus',
#  'Dominica',
#  'Costa Rica',
#  'Greece',
#  'Honduras',
#  'Saudi Arabia',
#  'United Arab Emirates',
#  'Bahrain',
#  'El Salvador',
#  'Switzerland',
#  'Cambodia',
#  'Spain',
#  'Luxembourg',
#  'Malaysia',
#  'Qatar',
#  'Australia',
#  'Poland',
#  'Bangladesh',
#  'Serbia',
#  'Netherlands',
#  'Egypt',
#  'Finland',
#  'Ukraine',
#  'France',
#  'Denmark',
#  'Russia',
#  'United States',
#  'Jordan']
