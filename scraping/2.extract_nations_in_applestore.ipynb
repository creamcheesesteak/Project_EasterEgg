# %%
# apple ios store 서비스 국가 추출

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import csv
import time
import re

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')

# %%
browser.get('https://support.apple.com/en-us/HT204411')

# %%
apple = 'https://support.apple.com/en-us/HT204411'

# %%
html= browser.page_source

# %%
soup= BeautifulSoup(html, 'html.parser')

# %%
soup.find_all("div", {"class": "grid3col"})
# Out:
# [<div class="grid3col">
#  <div><p><strong>Anguilla</strong></p>
#  <ul>
#  <li>Apple One</li>
#  <li>App Store<ul>
#  <li>Apple Arcade</li>
#  </ul>
#  </li>
#  <li>Apple Music<br/>
#  </li>
#  <li>iTunes Store<ul>
#  <li>Movies</li>
#  <li>Music</li>
#  <li>Ringtones &amp; Tones</li>
#  </ul>
#  </li>
#  <li>Apple TV app<ul>
#  <li>Apple TV+</li>
#  </ul>
#  </li>
#  <li>Apple Books<ul>
#  <li>Public domain books only</li>
#  </ul>
#  </li>
#  <li>Apple Podcasts</li>
#  </ul>
#  <p> </p>
#  <p><strong>Antigua and Barbuda</strong></p>
#  <ul>
#  <li>Apple One</li>
#  <li>App Store<ul>
#  <li>Apple Arcade</li>
#  </ul>
#  </li>
#  <li>Apple Music</li>
#  <li>iTunes Store<ul>
#  <li>Movies</li>
#  <li>Music</li>
#  <li>Ringtones &amp; Tones</li>
#  </ul>
#  </li>
#  <li>Apple TV app<ul>
#  <li>Apple TV+</li>
#  </ul>
#  </li>
#  <li>Apple Books<ul>
#  <li>Public domain books only</li>
#  </ul>
#  </li>
#  <li>Apple Podcasts</li>
#  </ul>
#  <p> </p>
# ...

# %%
totals = soup.find_all("div", {"class": "grid3col"})

# %%
totals[0]
# Out:
# <div class="grid3col">
# <div><p><strong>Anguilla</strong></p>
# <ul>
# <li>Apple One</li>
# <li>App Store<ul>
# <li>Apple Arcade</li>
# </ul>
# </li>
# <li>Apple Music<br/>
# </li>
# <li>iTunes Store<ul>
# <li>Movies</li>
# <li>Music</li>
# <li>Ringtones &amp; Tones</li>
# </ul>
# </li>
# <li>Apple TV app<ul>
# <li>Apple TV+</li>
# </ul>
# </li>
# <li>Apple Books<ul>
# <li>Public domain books only</li>
# </ul>
# </li>
# <li>Apple Podcasts</li>
# </ul>
# <p> </p>
# <p><strong>Antigua and Barbuda</strong></p>
# <ul>
# <li>Apple One</li>
# <li>App Store<ul>
# <li>Apple Arcade</li>
# </ul>
# </li>
# <li>Apple Music</li>
# <li>iTunes Store<ul>
# <li>Movies</li>
# <li>Music</li>
# <li>Ringtones &amp; Tones</li>
# </ul>
# </li>
# <li>Apple TV app<ul>
# <li>Apple TV+</li>
# </ul>
# </li>
# <li>Apple Books<ul>
# <li>Public domain books only</li>
# </ul>
# </li>
# <li>Apple Podcasts</li>
# </ul>
# <p> </p>
# <p><strong>Argentina</strong></p>
# <ul>
# <li>Apple One</li>
# <li>App Store<ul>
# ...

# %%
totals[0].find_all('strong')
# Out:
# [<strong>Anguilla</strong>,
#  <strong>Antigua and Barbuda</strong>,
#  <strong>Argentina</strong>,
#  <strong>Bahamas</strong>,
#  <strong>Barbados</strong>,
#  <strong>Belize</strong>,
#  <strong>Bermuda</strong>,
#  <strong>Bolivia</strong>,
#  <strong>Brazil</strong>,
#  <strong>British Virgin Islands</strong>,
#  <strong>Cayman Islands</strong>,
#  <strong>Chile</strong>]

# %%
ios_nations = []

for total in totals:
    nations = total.find_all('strong')
    ios_nations.append(nations)

# %%
ios_nations
# Out:
# [[<strong>Anguilla</strong>,
#   <strong>Antigua and Barbuda</strong>,
#   <strong>Argentina</strong>,
#   <strong>Bahamas</strong>,
#   <strong>Barbados</strong>,
#   <strong>Belize</strong>,
#   <strong>Bermuda</strong>,
#   <strong>Bolivia</strong>,
#   <strong>Brazil</strong>,
#   <strong>British Virgin Islands</strong>,
#   <strong>Cayman Islands</strong>,
#   <strong>Chile</strong>],
#  [<strong>Colombia</strong>,
#   <strong>Costa Rica</strong>,
#   <strong>Dominica</strong>,
#   <strong>Dominican Republic</strong>,
#   <strong>Ecuador</strong>,
#   <strong>El Salvador</strong>,
#   <strong>Grenada</strong>,
#   <strong>Guatemala</strong>,
#   <strong>Guyana</strong>,
#   <strong>Honduras</strong>,
#   <strong>Jamaica</strong>,
#   <strong>Mexico</strong>],
#  [<strong>Montserrat</strong>,
#   <strong>Nicaragua</strong>,
#   <strong>Panama</strong>,
#   <strong>Paraguay</strong>,
#   <strong>Peru</strong>,
#   <strong>St. Kitts and Nevis</strong>,
# ...

# %%
len(ios_nations)
# Out:
# 15

# %%
ios_nation = []
for i in ios_nations:
    ios_nation.extend(i)

# %%
ios_nation
# Out:
# [<strong>Anguilla</strong>,
#  <strong>Antigua and Barbuda</strong>,
#  <strong>Argentina</strong>,
#  <strong>Bahamas</strong>,
#  <strong>Barbados</strong>,
#  <strong>Belize</strong>,
#  <strong>Bermuda</strong>,
#  <strong>Bolivia</strong>,
#  <strong>Brazil</strong>,
#  <strong>British Virgin Islands</strong>,
#  <strong>Cayman Islands</strong>,
#  <strong>Chile</strong>,
#  <strong>Colombia</strong>,
#  <strong>Costa Rica</strong>,
#  <strong>Dominica</strong>,
#  <strong>Dominican Republic</strong>,
#  <strong>Ecuador</strong>,
#  <strong>El Salvador</strong>,
#  <strong>Grenada</strong>,
#  <strong>Guatemala</strong>,
#  <strong>Guyana</strong>,
#  <strong>Honduras</strong>,
#  <strong>Jamaica</strong>,
#  <strong>Mexico</strong>,
#  <strong>Montserrat</strong>,
#  <strong>Nicaragua</strong>,
#  <strong>Panama</strong>,
#  <strong>Paraguay</strong>,
#  <strong>Peru</strong>,
#  <strong>St. Kitts and Nevis</strong>,
#  <strong>St. Lucia</strong>,
# ...

# %%
type(ios_nation[0])
# Out:
# bs4.element.Tag

# %%
list = []
for i in ios_nation:
    element = i.text
#     element = str(i)
    list.append(element)
# Out:
# ['Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'Honduras',
#  'Jamaica',
#  'Mexico',
#  'Montserrat',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Suriname',
#  'Trinidad and Tobago',
#  'Turks and Caicos',
#  'Uruguay',
#  'Venezuela',
#  'Albania',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Latvia',
# ...

# %%
# list[0].repalce("<strong>", "'")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-99aaaac534a9> in <module>
# ----> 1 list[0].repalce("<strong>", "'")
#
# AttributeError: 'str' object has no attribute 'repalce'

# %%
iso_nation = list

# %%
iso_nation
# Out:
# ['Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'British Virgin Islands',
#  'Cayman Islands',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'Honduras',
#  'Jamaica',
#  'Mexico',
#  'Montserrat',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Suriname',
#  'Trinidad and Tobago',
#  'Turks and Caicos',
#  'Uruguay',
#  'Venezuela',
#  'Albania',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Latvia',
# ...

# %%
# for i in list:
#     i.repalce('</strong>', '')
#     i.repalce('</strong>', '')
