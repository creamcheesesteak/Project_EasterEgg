# %%
# google play store 서비스 국가 추출

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import csv
import time

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')

# %%
browser.get('https://support.google.com/googleplay/android-developer/answer/10532353?hl=en')

# %%
url = 'https://support.google.com/googleplay/android-developer/answer/10532353?hl=en'

# %%
html= browser.page_source

# %%
soup= BeautifulSoup(html, 'html.parser')

# %%
soup.find_all('table')[0]
# Out:
# <table class="nice-table">
# <thead>
# <tr>
# <th style="width: 25%;">
# <p>Location</p>
# </th>
# <th style="width: 25%;">Download free apps</th>
# <th>Download paid apps</th>
# <th>Buyer Currency and Price Range</th>
# </tr>
# <tr>
# <td>
# <p>Antigua and Barbuda</p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td>
# <p><span class="red-text"><span class="green-text">✔</span></span></p>
# </td>
# <td>★</td>
# </tr>
# <tr>
# <td>
# <p>Argentina</p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td>★</td>
# </tr>
# <tr>
# <td>
# <p>Aruba</p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td><span class="green-text">✔</span></td>
# <td>★</td>
# </tr>
# <tr>
# <td>
# <p>Bahamas</p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td>
# <p><span class="green-text">✔</span></p>
# </td>
# <td>★</td>
# </tr>
# <tr>
# <td>
# <p>Barbados</p>
# ...

# %%
pd.read_html(url)
# Out:
# [Empty DataFrame
# ...

# %%
len(pd.read_html(url))
# Out:
# 3

# %%
dfss = pd.read_html(url)

# %%
nation = []
for dfs in dfss:
    nations = dfs['Location']
    for i in nations:
        nation.append(i)
nation
# Out:
# [('Antigua and Barbuda',
#   'Argentina',
#   'Aruba',
#   'Bahamas',
#   'Barbados',
#   'Belize',
#   'Bermuda',
#   'Bolivia',
#   'Brazil',
#   'British Virgin Islands',
#   'Canada',
#   'Cayman Islands',
#   'Chile',
#   'Colombia',
#   'Costa Rica',
#   'Cuba',
#   'Dominica',
#   'Dominican Republic',
#   'Ecuador',
#   'El Salvador',
#   'Grenada',
#   'Guatemala',
#   'Haiti',
#   'Honduras',
#   'Jamaica',
#   'Mexico',
#   'Netherlands Antilles',
#   'Nicaragua',
#   'Panama',
#   'Paraguay',
#   'Peru',
#   'Rest of the World [1]',
#   'St. Kitts & Nevis',
#   'St. Lucia',
#   'Trinidad and Tobago',
#   'Turks and Caicos Islands',
#   'United States\xa0[3] [4]',
#   'Uruguay',
#   'Venezuela'),
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
# ...

# %%
nation[0]
# Out:
# ('Antigua and Barbuda',
#  'Argentina',
#  'Aruba',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Grenada',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Jamaica',
#  'Mexico',
#  'Netherlands Antilles',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Rest of the World [1]',
#  'St. Kitts & Nevis',
#  'St. Lucia',
#  'Trinidad and Tobago',
#  'Turks and Caicos Islands',
#  'United States\xa0[3] [4]',
#  'Uruguay',
#  'Venezuela')

# %%
c_nation = ['Antigua and Barbuda',
 'Argentina',
 'Aruba',
 'Bahamas',
 'Barbados',
 'Belize',
 'Bermuda',
 'Bolivia',
 'Brazil',
 'British Virgin Islands',
 'Canada',
 'Cayman Islands',
 'Chile',
 'Colombia',
 'Costa Rica',
 'Cuba',
 'Dominica',
 'Dominican Republic',
 'Ecuador',
 'El Salvador',
 'Grenada',
 'Guatemala',
 'Haiti',
 'Honduras',
 'Jamaica',
 'Mexico',
 'Netherlands Antilles',
 'Nicaragua',
 'Panama',
 'Paraguay',
 'Peru',
 'Rest of the World [1]',
 'St. Kitts & Nevis',
 'St. Lucia',
 'Trinidad and Tobago',
 'Turks and Caicos Islands',
 'United States\xa0[3] [4]',
 'Uruguay',
 'Venezuela']

# %%
len(c_nation), len(nation)
# Out:
# (39, 140)

# %%
len(nation)
# Out:
# 140

# %%
c_nation.extend(nation[1:])

# %%
len(c_nation)
# Out:
# 178

# %%
c_nation
# Out:
# ['Antigua and Barbuda',
#  'Argentina',
#  'Aruba',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'British Virgin Islands',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Grenada',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Jamaica',
#  'Mexico',
#  'Netherlands Antilles',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Rest of the World [1]',
#  'St. Kitts & Nevis',
#  'St. Lucia',
#  'Trinidad and Tobago',
#  'Turks and Caicos Islands',
#  'United States\xa0[3] [4]',
#  'Uruguay',
#  'Venezuela',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
# ...

# %%
#  [1], \xa0[3] [4],   ()

# %%
set_list = set(c_nation)
nation = list(set_list)

# %%
len(nation)
# Out:
# 178

# %%
refine = []
search1 = '['
search2 = '('
search3 = '0'
search4 = '"'

for i in nation:
    if search1 in i:
        refine.append(i)
        nation.remove(i)
    elif search2 in i:
        refine.append(i)
        nation.remove(i)
    elif search3 in i:
        refine.append(i)
        nation.remove(i)
    elif search4 in i:
        refine.append(i)
        nation.remove(i)

# %%
refine
# Out:
# ['Finland\xa0[6]',
#  'Ukraine\xa0[2]',
#  'Macedonia (FYROM)',
#  'Holy See (Vatican City\xa0State)',
#  'France\xa0[7]',
#  'Denmark\xa0[5]',
#  'Congo (DRC)',
#  'Russia\xa0[2]',
#  'Rest of the World [1]',
#  'United States\xa0[3] [4]']

# %%
len(refine)
# Out:
# 10

# %%
len(nation)
# Out:
# 168

# %%
m_refine = ['Finland', 'Ukraine', 'France', 'Denmark', 'Congo', 'Russia', 'United States']

# %%
nation.extend(m_refine)

# %%
len(nation)
# Out:
# 175

# %%
gp_nation = nation
gp_nation
# Out:
# ['Jordan',
#  'Turks and Caicos Islands',
#  'Mozambique',
#  'Ireland',
#  'Vietnam',
#  'Algeria',
#  'Latvia',
#  'Tajikistan',
#  'Laos',
#  'Gibraltar',
#  'Kuwait',
#  'Monaco',
#  'Slovenia',
#  'Angola',
#  'Singapore',
#  'Central African Republic',
#  'United Kingdom',
#  'Belgium',
#  'Argentina',
#  'Portugal',
#  'Romania',
#  'Colombia',
#  'Tanzania',
#  'Liechtenstein',
#  'Dominican Republic',
#  'Iraq',
#  'Israel',
#  'Samoa',
#  'Thailand',
#  'Czech Republic',
#  'Indonesia',
#  'Zambia',
#  'British Virgin Islands',
#  'Chad',
#  'Cuba',
#  'Venezuela',
#  'Sierra Leone',
#  'Bulgaria',
#  'Lithuania',
#  'Tunisia',
#  'Georgia',
#  'St. Lucia',
#  'Taiwan',
#  'South Korea',
#  'Suriname',
#  'Austria',
#  'Azerbaijan',
#  'Macau',
#  'Eritrea',
#  'Cape Verde',
#  'Guinea-Bissau',
#  'Senegal',
#  'Tonga',
#  'Germany',
#  'Yemen',
#  'Oman',
#  'Guatemala',
#  'Mauritius',
#  'Moldova',
#  'Zimbabwe',
#  "Cote d'Ivoire",
#  'Hungary',
#  'Nicaragua',
# ...
