# %%
# Appannie 용 스크래퍼
# 작동을 위해서는 사전에 로그인 값과 스크래핑할 데이터 정보 입력 필요
# 스크래퍼 작동을 위해 다른 창은 내려 주시고, 작동 동안 컴퓨터 활용이 불가능함을 알림
# 팝업화면이 top에 위치 & 페이지크기 full & 화면배울 100% 기준
# 시작부터 .xls 저장까지 한 사이클 4:15분 소요

# %%
# 배운 라이브러리
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import csv
import time

# %%
# 찾아본 라이브러리
import pyautogui as gui # 마우스 이동, 키보드 입력
import pyperclip # 클립보드 사용

# %%
# 로그인 값과 찾을 데이터 값을 입력하시오

# 로그인 yours = ['아이디', '비밀번호']  Ex.['abc@naver.com', 'qwe']
yours = ['000@000.com', '000000']

# 찾는 데이터 : data = ['ios/gp', 'free/paid', 'nation nation (need to space)'] Ex.['ios','free','SOUTH KOREA'] 
data = ['ios','free','SOUTH KOREA']

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')

# %%
browser.get('https://www.appannie.com/account/login')

# %%
# 스크래퍼 작동을 위해 화면이 top에 위치 & 페이지크기 full
browser.maximize_window()

# %%
# ID
browser.find_element_by_name("username").send_keys(yours[0])
# PASSWORD
browser.find_element_by_xpath("//input[@type='password']").send_keys(yours[1])

# %%
# log-in
browser.find_element_by_xpath("//button[@type='submit']").click()

# %%
ios = browser.get('https://www.appannie.com/intelligence/top-apps/store-rank/ios')
gp = browser.get('https://www.appannie.com/intelligence/top-apps/store-rank/gp') # google play store
data[0] # 모바일 시장 선택
# Out:
# 'ios'

# %%
# browser.find_element_by_name("ViewSwitcher--top-apps").click()
if (data[1] == 'free'):
    free = browser.find_element_by_xpath("//button[@title='view-all-free']").click()
else:
    paid = browser.find_element_by_xpath("//button[@title='view-all-paid']").click()

# %%
nation = browser.find_element_by_xpath("//input[@aria-activedescendant='react-select-SingleCountryPicker--store_rank_release_time_as_date_capacity--value']")
nation.send_keys(data[2]) # 국가명 입력
nation.send_keys(Keys.RETURN)

# %%
browser.implicitly_wait(3)

# %%
html= browser.page_source

# %%
browser.find_element_by_xpath("//div[@data-testid='table-header-content']").click()

# %%
browser.execute_script("window.scrollTo(0, 0)")

# %%
browser.execute_script("window.scrollTo(0, 890)")

# %%
contents = []

# 1 ~ 91 순위까지
for i in range(1, 92):
    gui.moveTo(490,236, 0.4)
    gui.dragTo(1080, 295, 0.8, button='left')
    gui.hotkey('ctrl','c')
    a = pyperclip.paste()
    gui.click()
    gui.scroll(-60)
    list = a.split('\r')
    list = [i.strip('\n') for i in list]
    if len(list) == 3:
        list.insert(2, '없음')
        contents.append(list)
        continue
    elif list[-1] == '':
        del list[-1]
        list.insert(2, '없음')
        continue
    elif len(list) == 4:
        contents.append(list)
        continue

# %%
# 92 ~ 100 순위 까지 (마지막은 스크롤을 내릴 수 없어서 따로 for문 작성)
for i in range(1,10):
    n = 75 * (i-1)
    gui.moveTo(490,236+int(n), 0.5)
    gui.dragTo(1080, 285+int(n), 1,button='left')
    gui.hotkey('ctrl','c')
    a = pyperclip.paste()
    gui.click()
    list = a.split('\r')
    list = [i.strip('\n') for i in list]
    if len(list) == 3:
        list.insert(2, '없음')
        contents.append(list)
        continue
    elif list[-1] == '':
        del list[-1]
        list.insert(2, '없음')
        continue
    elif len(list) == 4:
        contents.append(list)
        continue

# %%
len(contents)
# Out:
# 100

# %%
contents
# Out:
# [['', '질병관리청 COOV(코로나19 전자예방접종증명서)', '질병관리본부', 'Medical (Applications)'],
#  ['', '디 앤츠:언더그라운드 킹덤', 'StarUnion', 'Strategy (Games)'],
#  ['', 'K무협', 'Kingkong Soft', 'Role Playing (Games)'],
#  ['', 'Fidget Trading 3D - Fidget Toys', 'Maglab Turkey', 'Casual (Games)'],
#  ['', 'Brain Riddle - Tricky Puzzles', 'Arrasol', 'Puzzle (Games)'],
#  ['', '퀸잇 - 4050 브랜드 쇼핑앱', '라포랩스', 'Shopping (Applications)'],
#  ['', '오딘: 발할라 라이징', 'Kakao', 'Role Playing (Games)'],
#  ['', 'Trading Master', 'Follow Circles', 'Simulation (Games)'],
#  ['',
#   'Coupang Eats - Rocket Delivery for Food',
#   '없음',
#   'Food & Drink (Applications)'],
#  ['', 'LG전자 LGE.COM', 'LG Electronics', 'Shopping (Applications)'],
#  ['',
#   'ZOOM Cloud Meetings',
#   'Zoom Video Communications',
#   'Business (Applications)'],
#  ['',
#   'Karrot - Your local buying & selling community',
#   'Danggeun Market',
#   'Social (Applications)'],
#  ['',
#   "KB증권 'M-able' (마블) - 대표MTS (비대면계좌개설 포함)",
#   'KB Securities',
#   'Finance (Applications)'],
#  ['', '청약홈', 'Korea Appraisal Board', 'Finance (Applications)'],
#  ['', '브랜디 – 하루배송', 'Brandi', 'Shopping (Applications)'],
#  ['',
#   'TMAP - 내비게이션 / 지도',
#   'TMAP MOBILITY',
#   'Maps & Navigation (Applications)'],
#  ['', '오늘의집 - No.1 인테리어 필수앱', 'Bucketplace', 'Shopping (Applications)'],
#  ['', '배달의민족', 'Woowa Brothers', 'Food & Drink (Applications)'],
#  ['',
#   '정부24(구 민원24)',
#   'Ministry of the Interior and Safety',
#   'Productivity (Applications)'],
#  ['', 'Time Princess', 'IGG', 'Role Playing (Games)'],
#  ['',
#   'Count Masters: Crowd Clash & Stickman running game',
#   'Ascella Mobile',
#   'Action (Games)'],
#  ['', '토스', 'Viva Republica', 'Finance (Applications)'],
#  ['',
#   'what3words: Never get lost again',
#   'what3words',
#   'Maps & Navigation (Applications)'],
#  ['', '히어로즈 테일즈', '37games', 'Role Playing (Games)'],
#  ['', 'Crazy Eraser', 'MASK', 'Puzzle (Games)'],
#  ['', 'Netflix', 'Netflix', 'Entertainment (Applications)'],
#  ['',
#   '야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 레저, 렌터카, KTX 최대 80% 할인',
#   'Yanolja',
#   'Travel & Local (Applications)'],
#  ['',
#   'Samsung TV Plus: 100% Free TV.',
#   'Samsung Electronics',
#   'Entertainment (Applications)'],
#  ['', 'KakaoTalk: Free Calls & Text', 'Kakao', 'Communication (Applications)'],
#  ['',
#   '티빙(TVING) - 실시간TV, 방송VOD, 영화VOD',
#   'CJ ENM',
#   'Entertainment (Applications)'],
#  ['', 'Sunday night for FNF music battle', '없음', 'Music (Games)'],
#  ['',
#   'The건강보험(더건강보험)',
#   'National Health Insurance Corporation',
#   'Health & Fitness (Applications)'],
#  ['', 'KakaoMap - Map / Navigation', 'Kakao', 'Travel & Local (Applications)'],
#  ['',
#   'Fidget Toys Trading: fidget trade relaxing games',
#   '없음',
#   'Puzzle (Games)'],
#  ['',
#   'Judgement Day: Heaven or Hell, Oh my God!',
#   'Matchingham Games',
#   'Simulation (Games)'],
#  ['', '쿠팡 (Coupang)', '없음', 'Shopping (Applications)'],
#  ['', '질병관리청 예방접종도우미', '질병관리본부', 'Health & Fitness (Applications)'],
#  ['', 'Balls Duel', 'Voodoo', 'Arcade (Games)'],
#  ['', 'Instagram', 'Instagram', 'Social (Applications)'],
#  ['',
#   'Samsung Smart Switch Mobile',
#   'Samsung Electronics',
#   'Tools (Applications)'],
#  ['',
#   '배달요기요 - 기다림 없는 맛집 배달앱',
#   'Delivery Hero Korea',
#   'Food & Drink (Applications)'],
#  ['', '교촌치킨', 'Kyochon', 'Food & Drink (Applications)'],
#  ['', 'GS SHOP', 'GS Retail', 'Shopping (Applications)'],
#  ['', '카카오뱅크', 'Kakao Bank', 'Finance (Applications)'],
#  ['', 'Coupang Play', '없음', 'Entertainment (Applications)'],
#  ['', 'TikTok', 'TikTok Pte Ltd', 'Video Players & Editors (Applications)'],
#  ['', '네이버 - NAVER', 'NAVER', 'Books & Reference (Applications)'],
#  ['',
#   'Kakao T - Taxi, Driver, Parking, Navi, Bike, Train',
#   'Kakao Mobility',
#   'Maps & Navigation (Applications)'],
#  ['', 'Hero Tower Wars - Math Puzzle', 'Ohze', 'Casual (Games)'],
#  ['', '드래곤라자EX', '없음', 'Role Playing (Games)'],
#  ['', '맘스터치', '없음', 'Food & Drink (Applications)'],
#  ['', '모빌리언스카드', 'Mobilians', 'Finance (Applications)'],
#  ['', 'Magic Tiles 3', 'Amanotes', 'Music (Games)'],
#  ['',
#   '자가격리자 안전보호',
#   'Ministry of the Interior and Safety',
#   'Lifestyle (Applications)'],
#  ['', '슬레이어 키우기', 'GEAR2', 'Simulation (Games)'],
#  ['',
#   '스마트위택스',
#   'Ministry of the Interior and Safety',
#   'Finance (Applications)'],
#  ['', '에이블리 - 2천만의 AI 쇼핑메이트', '없음', 'Shopping (Applications)'],
#  ['',
#   '여기어때 - 호텔, 모텔, 펜션, 캠핑, 게하, 모바일티켓 최저가 예약!',
#   '없음',
#   'Travel & Local (Applications)'],
#  ['', '카카오페이', 'Kakao', 'Finance (Applications)'],
#  ['', 'The Walking Dead: Survivors', 'Elex Technology', 'Strategy (Games)'],
#  ['', '마켓컬리-내일의 장보기', 'Kurly', 'Food & Drink (Applications)'],
#  ['', 'Elemental Master', 'Supersonic', 'Action (Games)'],
#  ['', 'V3 Mobile Plus', 'AhnLab', 'Tools (Applications)'],
#  ['', 'OP:Adventure of Pirates', '없음', 'Adventure (Games)'],
#  ['', '지그재그 - 내 맘대로 쇼핑앱', 'croquis', 'Shopping (Applications)'],
#  ['', 'Pixel Paint!', 'Translimit', 'Puzzle (Games)'],
#  ['', 'Droid-X III 백신 (기업용)', 'NSHC', 'Tools (Applications)'],
#  ['', '삼성카드', 'Samsung Card', 'Finance (Applications)'],
#  ['', 'QR & Barcode Reader', 'TeaCapps', 'Productivity (Applications)'],
#  ['', '냥코 대전쟁', 'PONOS', 'Casual (Games)'],
#  ['', 'Bridge Race', 'Supersonic', 'Casual (Games)'],
#  ['', 'Delete Puzzle: Erase One Part', 'Zego Studio', 'Puzzle (Games)'],
#  ['', '랜덤투유 - 두근두근 5천원 랜덤쇼핑', 'random2u', 'Shopping (Applications)'],
#  ['', 'Hair Challenge', 'Rollic', 'Action (Games)'],
#  ['', '다방 – 대한민국 대표 부동산 앱', 'Station3', 'House & Home (Applications)'],
#  ['', 'NH스마트뱅킹', 'Nonghyup', 'Finance (Applications)'],
#  ['', 'ZEPETO', 'SNOW, Inc.', 'Entertainment (Applications)'],
#  ['', 'Brain Rush - Brain Hole Bang', 'MNMFUN', 'Puzzle (Games)'],
#  ['', '푹 (pooq)', 'Wavve', 'Entertainment (Applications)'],
#  ['', '올리브영', 'CJ OliveNetworks', 'Shopping (Applications)'],
#  ['', 'EF 디펜스', 'ekkorr', 'Simulation (Games)'],
#  ['', '남성앱 하이버', 'Brandi', 'Shopping (Applications)'],
#  ['', '삼국지군웅전', '없음', 'Strategy (Games)'],
#  ['', '국세청 홈택스 [손택스]', 'National Tax Service Korea', 'Tools (Applications)'],
#  ['', 'Alchemy Stars', 'Proxima Beta', 'Role Playing (Games)'],
#  ['', 'lotte.com', 'Lotte', 'Shopping (Applications)'],
#  ['',
#   'Discord - Talk, Video Chat & Hang Out with Friends',
#   'Discord',
#   'Communication (Applications)'],
#  ['', 'Infinite Stairs', 'NFLY STUDIO', 'Arcade (Games)'],
#  ['', '1945 Air Force: Airplane games', 'OneSoft', 'Arcade (Games)'],
#  ['', '한국투자증권 (계좌개설 포함)', 'Korea Investment', 'Finance (Applications)'],
#  ['', 'NAVER Map, Navigation', 'NAVER', 'Travel & Local (Applications)'],
#  ['', '번개장터 - 취향을 잇는 중고거래', 'Quicket', 'Shopping (Applications)'],
#  ['', '하나원큐 - 하나은행 스마트폰 뱅킹', 'KEB Hana Bank', 'Finance (Applications)'],
#  ['', '제주안심코드', '제주특별자치도', 'Health & Fitness (Applications)'],
#  ['', 'WATCHA', 'Watcha', 'Entertainment (Applications)'],
#  ['', 'Zigbang', 'Channelbreeze', 'House & Home (Applications)'],
#  ['', '해피오더', 'SPC Group', 'Lifestyle (Applications)'],
#  ['', 'Beat Cat', 'Wonder Game', 'Casual (Games)'],
#  ['', '클로바노트 - AI 음성기록', 'NAVER', 'Productivity (Applications)'],
#  ['', '우리WON카드', 'Woori Card', 'Finance (Applications)']]

# %%
# 드래그시 열의 마지막 str에서 긴 (Application) 의 경우 1~2문자의 누락가능성 확인 -> 조정하기위한 for문

for content in contents:
    if content[-1][-1] == 'n':
        content[-1] = content[-1] + 's)'
    elif content[-1][-1] == 'o':
        content[-1] = content[-1] + 'ns)'
    elif content[-1][-1] == 's':
        if (content[-1] == 'Games') or (content[-1] == 'Kids'):
            break
        else:
            content[-1] = content[-1] + ')'

# %%
pd.set_option('display.max_row', 101)
pd.set_option('display.max_columns', 10)

# %%
df = pd.DataFrame(data = contents, columns = ['-', '앱이름','회사명','카테고리'])
df.index = df.index + 1
df = df.drop(columns = ['-'])
df
# Out:
#                                                    앱이름  \
# 1                          질병관리청 COOV(코로나19 전자예방접종증명서)
# 2                                       디 앤츠:언더그라운드 킹덤
# 3                                                  K무협
# 4                      Fidget Trading 3D - Fidget Toys
# 5                        Brain Riddle - Tricky Puzzles
# 6                                    퀸잇 - 4050 브랜드 쇼핑앱
# 7                                          오딘: 발할라 라이징
# 8                                       Trading Master
# 9              Coupang Eats - Rocket Delivery for Food
# 10                                        LG전자 LGE.COM
# 11                                 ZOOM Cloud Meetings
# 12      Karrot - Your local buying & selling community
# 13             KB증권 'M-able' (마블) - 대표MTS (비대면계좌개설 포함)
# 14                                                 청약홈
# 15                                          브랜디 – 하루배송
# 16                                   TMAP - 내비게이션 / 지도
# 17                                오늘의집 - No.1 인테리어 필수앱
# 18                                               배달의민족
# 19                                        정부24(구 민원24)
# 20                                       Time Princess
# 21   Count Masters: Crowd Clash & Stickman running ...
# 22                                                  토스
# 23                    what3words: Never get lost again
# 24                                            히어로즈 테일즈
# 25                                        Crazy Eraser
# 26                                             Netflix
# 27    야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 레저, 렌터카, KTX 최대 80% 할인
# 28                      Samsung TV Plus: 100% Free TV.
# 29                        KakaoTalk: Free Calls & Text
# 30                     티빙(TVING) - 실시간TV, 방송VOD, 영화VOD
# 31                   Sunday night for FNF music battle
# 32                                      The건강보험(더건강보험)
# 33                         KakaoMap - Map / Navigation
# 34    Fidget Toys Trading: fidget trade relaxing games
# 35           Judgement Day: Heaven or Hell, Oh my God!
# 36                                        쿠팡 (Coupang)
# 37                                       질병관리청 예방접종도우미
# 38                                          Balls Duel
# 39                                           Instagram
# 40                         Samsung Smart Switch Mobile
# 41                               배달요기요 - 기다림 없는 맛집 배달앱
# 42                                                교촌치킨
# 43                                             GS SHOP
# 44                                               카카오뱅크
# 45                                        Coupang Play
# 46                                              TikTok
# 47                                         네이버 - NAVER
# 48   Kakao T - Taxi, Driver, Parking, Navi, Bike, T...
# 49                       Hero Tower Wars - Math Puzzle
# 50                                             드래곤라자EX
# 51                                                맘스터치
# 52                                             모빌리언스카드
# 53                                       Magic Tiles 3
# 54                                          자가격리자 안전보호
# 55                                            슬레이어 키우기
# 56                                              스마트위택스
# 57                                에이블리 - 2천만의 AI 쇼핑메이트
# 58            여기어때 - 호텔, 모텔, 펜션, 캠핑, 게하, 모바일티켓 최저가 예약!
# 59                                               카카오페이
# 60                         The Walking Dead: Survivors
# 61                                        마켓컬리-내일의 장보기
# 62                                    Elemental Master
# 63                                      V3 Mobile Plus
# 64                             OP:Adventure of Pirates
# 65                                    지그재그 - 내 맘대로 쇼핑앱
# 66                                        Pixel Paint!
# 67                                Droid-X III 백신 (기업용)
# 68                                                삼성카드
# 69                                 QR & Barcode Reader
# 70                                              냥코 대전쟁
# 71                                         Bridge Race
# 72                       Delete Puzzle: Erase One Part
# 73                                랜덤투유 - 두근두근 5천원 랜덤쇼핑
# 74                                      Hair Challenge
# 75                                  다방 – 대한민국 대표 부동산 앱
# 76                                             NH스마트뱅킹
# 77                                              ZEPETO
# 78                        Brain Rush - Brain Hole Bang
# 79                                            푹 (pooq)
# 80                                                올리브영
# 81                                              EF 디펜스
# 82                                             남성앱 하이버
# 83                                              삼국지군웅전
# 84                                       국세청 홈택스 [손택스]
# 85                                       Alchemy Stars
# 86                                           lotte.com
# 87   Discord - Talk, Video Chat & Hang Out with Fri...
# 88                                     Infinite Stairs
# 89                      1945 Air Force: Airplane games
# 90                                    한국투자증권 (계좌개설 포함)
# 91                               NAVER Map, Navigation
# 92                                  번개장터 - 취향을 잇는 중고거래
# 93                                 하나원큐 - 하나은행 스마트폰 뱅킹
# 94                                              제주안심코드
# 95                                              WATCHA
# 96                                             Zigbang
# 97                                                해피오더
# 98                                            Beat Cat
# 99                                     클로바노트 - AI 음성기록
# 100                                            우리WON카드
#
#                                        회사명  \
# 1                                   질병관리본부
# 2                                StarUnion
# 3                            Kingkong Soft
# 4                            Maglab Turkey
# 5                                  Arrasol
# 6                                     라포랩스
# 7                                    Kakao
# 8                           Follow Circles
# 9                                       없음
# 10                          LG Electronics
# 11               Zoom Video Communications
# 12                         Danggeun Market
# 13                           KB Securities
# 14                   Korea Appraisal Board
# 15                                  Brandi
# 16                           TMAP MOBILITY
# 17                             Bucketplace
# 18                          Woowa Brothers
# 19     Ministry of the Interior and Safety
# 20                                     IGG
# 21                          Ascella Mobile
# 22                          Viva Republica
# 23                              what3words
# 24                                 37games
# 25                                    MASK
# 26                                 Netflix
# 27                                 Yanolja
# 28                     Samsung Electronics
# 29                                   Kakao
# 30                                  CJ ENM
# 31                                      없음
# 32   National Health Insurance Corporation
# 33                                   Kakao
# 34                                      없음
# 35                       Matchingham Games
# 36                                      없음
# 37                                  질병관리본부
# 38                                  Voodoo
# 39                               Instagram
# 40                     Samsung Electronics
# 41                     Delivery Hero Korea
# 42                                 Kyochon
# 43                               GS Retail
# 44                              Kakao Bank
# 45                                      없음
# 46                          TikTok Pte Ltd
# 47                                   NAVER
# 48                          Kakao Mobility
# 49                                    Ohze
# 50                                      없음
# 51                                      없음
# 52                               Mobilians
# 53                                Amanotes
# 54     Ministry of the Interior and Safety
# 55                                   GEAR2
# 56     Ministry of the Interior and Safety
# 57                                      없음
# 58                                      없음
# 59                                   Kakao
# 60                         Elex Technology
# 61                                   Kurly
# 62                              Supersonic
# 63                                  AhnLab
# 64                                      없음
# 65                                 croquis
# 66                              Translimit
# 67                                    NSHC
# 68                            Samsung Card
# 69                                TeaCapps
# 70                                   PONOS
# 71                              Supersonic
# 72                             Zego Studio
# 73                                random2u
# 74                                  Rollic
# 75                                Station3
# 76                                Nonghyup
# 77                              SNOW, Inc.
# 78                                  MNMFUN
# 79                                   Wavve
# 80                        CJ OliveNetworks
# 81                                  ekkorr
# 82                                  Brandi
# 83                                      없음
# 84              National Tax Service Korea
# 85                            Proxima Beta
# 86                                   Lotte
# 87                                 Discord
# 88                             NFLY STUDIO
# 89                                 OneSoft
# 90                        Korea Investment
# 91                                   NAVER
# 92                                 Quicket
# 93                           KEB Hana Bank
# 94                                 제주특별자치도
# 95                                  Watcha
# 96                           Channelbreeze
# 97                               SPC Group
# 98                             Wonder Game
# 99                                   NAVER
# 100                             Woori Card
#
#                                        카테고리
# 1                    Medical (Applications)
# 2                          Strategy (Games)
# 3                      Role Playing (Games)
# 4                            Casual (Games)
# 5                            Puzzle (Games)
# 6                   Shopping (Applications)
# 7                      Role Playing (Games)
# 8                        Simulation (Games)
# 9               Food & Drink (Applications)
# 10                  Shopping (Applications)
# 11                  Business (Applications)
# 12                    Social (Applications)
# 13                   Finance (Applications)
# 14                   Finance (Applications)
# 15                  Shopping (Applications)
# 16         Maps & Navigation (Applications)
# 17                  Shopping (Applications)
# 18              Food & Drink (Applications)
# 19              Productivity (Applications)
# 20                     Role Playing (Games)
# 21                           Action (Games)
# 22                   Finance (Applications)
# 23         Maps & Navigation (Applications)
# 24                     Role Playing (Games)
# 25                           Puzzle (Games)
# 26             Entertainment (Applications)
# 27            Travel & Local (Applications)
# 28             Entertainment (Applications)
# 29             Communication (Applications)
# 30             Entertainment (Applications)
# 31                            Music (Games)
# 32          Health & Fitness (Applications)
# 33            Travel & Local (Applications)
# 34                           Puzzle (Games)
# 35                       Simulation (Games)
# 36                  Shopping (Applications)
# 37          Health & Fitness (Applications)
# 38                           Arcade (Games)
# 39                    Social (Applications)
# 40                     Tools (Applications)
# 41              Food & Drink (Applications)
# 42              Food & Drink (Applications)
# 43                  Shopping (Applications)
# 44                   Finance (Applications)
# 45             Entertainment (Applications)
# 46   Video Players & Editors (Applications)
# 47         Books & Reference (Applications)
# 48         Maps & Navigation (Applications)
# 49                           Casual (Games)
# 50                     Role Playing (Games)
# 51              Food & Drink (Applications)
# 52                   Finance (Applications)
# 53                            Music (Games)
# 54                 Lifestyle (Applications)
# 55                       Simulation (Games)
# 56                   Finance (Applications)
# 57                  Shopping (Applications)
# 58            Travel & Local (Applications)
# 59                   Finance (Applications)
# 60                         Strategy (Games)
# 61              Food & Drink (Applications)
# 62                           Action (Games)
# 63                     Tools (Applications)
# 64                        Adventure (Games)
# 65                  Shopping (Applications)
# 66                           Puzzle (Games)
# 67                     Tools (Applications)
# 68                   Finance (Applications)
# 69              Productivity (Applications)
# 70                           Casual (Games)
# 71                           Casual (Games)
# 72                           Puzzle (Games)
# 73                  Shopping (Applications)
# 74                           Action (Games)
# 75              House & Home (Applications)
# 76                   Finance (Applications)
# 77             Entertainment (Applications)
# 78                           Puzzle (Games)
# 79             Entertainment (Applications)
# 80                  Shopping (Applications)
# 81                       Simulation (Games)
# 82                  Shopping (Applications)
# 83                         Strategy (Games)
# 84                     Tools (Applications)
# 85                     Role Playing (Games)
# 86                  Shopping (Applications)
# 87             Communication (Applications)
# 88                           Arcade (Games)
# 89                           Arcade (Games)
# 90                   Finance (Applications)
# 91            Travel & Local (Applications)
# 92                  Shopping (Applications)
# 93                   Finance (Applications)
# 94          Health & Fitness (Applications)
# 95             Entertainment (Applications)
# 96              House & Home (Applications)
# 97                 Lifestyle (Applications)
# 98                           Casual (Games)
# 99              Productivity (Applications)
# 100                  Finance (Applications)

# %% [markdown]
# 카테고리
#
# * Games : Action, Adventure, Board, Card, Casino, Casual, Dice, Education, Family, Kids, Music, Puzzle, Racing, Role Playing, Simulation, Sports, Strategy, Trivia, Word
#
# * Applications : Books, Business, Catalogs, Developer Tools, Education, Entertainment, Finance, Food and Drink, Graphics & Design, Health and Fitness, Lifestyle, Magazines and Newspapers, Medical, Music, Navigation, News, Photo and Video, Productivity, Reference, Shopping, Social Networking, Sports, Travel, Utilities, Weather
#
# * Kids : Ages 5 & Under, Ages 6-8, Ages 9-11

# %%
# 회사명 中 None 은 '없음' 으로 본다

# %%
# 데이터에 맞는 이름으로 엑셀 생성 Ex. '시장_국가명_랭킹수_무료/유료'
loot = 'C:/pl/scraping/'
name = loot + data[0] + '_' + data[2] + '_' + str(len(df.index)) + '_' + data[1] + '.xls'
df.to_excel(name)
